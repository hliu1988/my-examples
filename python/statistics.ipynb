# %%
import statistics

vals=[1,2,3,4,5]
cur_avg = statistics.mean(vals)
m1 = max(vals)
m2 = min(vals)
print(cur_avg, m1, m2)


diff1 = 1 - m2/cur_avg
diff2 = m1/cur_avg - 1
print(max(diff1, diff2))
# Out:
# 3 5 1
# 0.6666666666666667
