# %%
x = 10
if x > 5:
    print("x is greater than 5")
elif x == 5:
    print("x is equal to 5")
else:
    print("x is less than 5")
# Out:
# x is greater than 5

# %%
# for loop

for i in range(5):
    print(i)

sum = 0

for i in range(5):
    sum += i
    print(f'Sum: {sum}')

fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    if fruit[0] in ['a', 'o', 'u', 'e', 'i']:
        print(f'I eat an {fruit}.')
    else:
        print(f'I eat a {fruit}.')
# Out:
# 0
# 1
# 2
# 3
# 4
# Sum: 0
# Sum: 1
# Sum: 3
# Sum: 6
# Sum: 10
# I eat an apple.
# I eat a banana.
# I eat a cherry.

# %%
x = 0
while x < 5:
    print(x)
    x += 1

print()
for i in range(5):
    if i == 3:
        break
    print(i)

print()
for i in range(5):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
#
# 0
# 1
# 2
#
# 0
# 1
# 2
# 4

# %%
# 求解sqrt
integer_number = 25
accuracy = 0.01

if integer_number < 0:
    print("There is no true square root of a negative number.")

else:
    minimum = 0
    maximum = max(1, integer_number)
    number_of_iterations = 0
    midpoint = (maximum + minimum) / 2

    while abs(midpoint**2 - integer_number) >= accuracy:
        print(f"iter={number_of_iterations}: minimum={minimum}, maximum={maximum}, midpoint={midpoint}")
        if midpoint**2 < integer_number:
            minimum = midpoint
        else:
            maximum = midpoint
        midpoint = (maximum + minimum) / 2
        number_of_iterations += 1

    print(
        f"After {number_of_iterations} iterations, the bisection search algorithm found {midpoint} to be close to the square root of {integer_number} with an accuracy of {accuracy}. "
    )
# Out:
# iter=0: minimum=0, maximum=25, midpoint=12.5
# iter=1: minimum=0, maximum=12.5, midpoint=6.25
# iter=2: minimum=0, maximum=6.25, midpoint=3.125
# iter=3: minimum=3.125, maximum=6.25, midpoint=4.6875
# iter=4: minimum=4.6875, maximum=6.25, midpoint=5.46875
# iter=5: minimum=4.6875, maximum=5.46875, midpoint=5.078125
# iter=6: minimum=4.6875, maximum=5.078125, midpoint=4.8828125
# iter=7: minimum=4.8828125, maximum=5.078125, midpoint=4.98046875
# iter=8: minimum=4.98046875, maximum=5.078125, midpoint=5.029296875
# iter=9: minimum=4.98046875, maximum=5.029296875, midpoint=5.0048828125
# iter=10: minimum=4.98046875, maximum=5.0048828125, midpoint=4.99267578125
# iter=11: minimum=4.99267578125, maximum=5.0048828125, midpoint=4.998779296875
# iter=12: minimum=4.998779296875, maximum=5.0048828125, midpoint=5.0018310546875
# After 13 iterations, the bisection search algorithm found 5.00030517578125 to be close to the square root of 25 with an accuracy of 0.01.

# %%
# Prime Number Checker Program 检查素数
# 一个大于 1的自然数，除了 1 和它本身之外，没有其他正因数（无法被其他自然数整除）。
numbers = [2, 3, 4, 5, 10, 13, 17, 19, 23, 24, 29]
prime_status = {}

for number in numbers:
    if number < 2:
        prime_status[number] = False
    elif number == 2:
        prime_status[number] = True
    else:
        is_prime = True
        for i in range(2, int(number ** 0.5) + 1):
            if number % i == 0:
                is_prime = False
                break
        prime_status[number] = is_prime

print("Prime Status of Numbers:")
for num, status in prime_status.items():
    print(f"{num}: {'Prime' if status else 'Not Prime'}")
# Out:
# Prime Status of Numbers:
# 2: Prime
# 3: Prime
# 4: Not Prime
# 5: Prime
# 10: Not Prime
# 13: Prime
# 17: Prime
# 19: Prime
# 23: Prime
# 24: Not Prime
# 29: Prime
