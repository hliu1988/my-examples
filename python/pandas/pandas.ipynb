# %%
import pandas as pd

# %%
data = {
  "Duration": [50, 40, None, None, 90, 20],
  "Pulse": [109, 140, 110, 125, 138, 170]
}
df = pd.DataFrame(data)

# column exist?
print("Seconds" in df.columns)
# only count real value, ignore NA
print(df['Duration'].count())
# get result except the last cell
print(df['Duration'][:-1].count())
# check NaN or not-NaN
# print(df['Duration'].isna()) # print(df['Duration'].notna())
# Out:
# False
# 4
# 3
