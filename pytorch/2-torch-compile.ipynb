# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 定义一个简单的模型
class SimpleModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Conv2d(3, 16, 3)
        self.relu = nn.ReLU()
        self.fc = nn.Linear(16*30*30, 10)  # 假设输入是3x32x32

    def forward(self, x):
        x = self.conv(x)
        x = self.relu(x)
        x = x.flatten(1)
        x = self.fc(x)
        return x

# 1. 初始化模型
model = SimpleModel()
# 2. 用torch.compile编译模型（核心步骤）
model = torch.compile(model)  # 一行代码完成编译

# 后续训练/推理代码完全不变
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# 模拟训练
for epoch in range(2):
    # 模拟输入：batch_size=8, channel=3, size=32x32
    inputs = torch.randn(8, 3, 32, 32)
    labels = torch.randint(0, 10, (8,))
    
    optimizer.zero_grad()
    outputs = model(inputs)  # 编译后的模型调用方式不变
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")

# 推理时同样可用
with torch.no_grad():
    test_input = torch.randn(1, 3, 32, 32)
    pred = model(test_input)
    print(f"推理输出形状: {pred.shape}")
# Out:
# Epoch 1, Loss: 2.2968
# Epoch 2, Loss: 3.1528
# 推理输出形状: torch.Size([1, 10])

# %%
import torch
import torch.nn as nn

class SimpleModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Conv2d(3, 16, 3)
        self.bn = nn.BatchNorm2d(16)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        return x

model = SimpleModel().eval()
x = torch.randn(1, 3, 32, 32)

# 一键编译模型（自动做图优化+算子优化）
compiled_model = torch.compile(model)

# 第一次执行：编译+执行（有编译开销）
compiled_output = compiled_model(x)
# 后续执行：直接运行优化后的图（无编译开销）
compiled_output = compiled_model(x)

# 验证结果一致性
print(torch.allclose(model(x), compiled_output))  # True
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 21
#      18 x = torch.randn(1, 3, 32, 32)
#      20 # 一键编译模型（自动做图优化+算子优化）
# ---> 21 compiled_model = torch.compile(model)
#      23 # 第一次执行：编译+执行（有编译开销）
#      24 compiled_output = compiled_model(x)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/__init__.py:2447, in compile(model, fullgraph, dynamic, backend, mode, options, disable)
#    2444 else:
#    2445     backend = _TorchCompileWrapper(backend, mode, options, dynamic)
# -> 2447 return torch._dynamo.optimize(
#    2448     backend=backend,
#    2449     nopython=fullgraph,
#    2450     dynamic=dynamic,
#    2451     disable=disable,
#    2452 )(model)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:716, in optimize(*args, **kwargs)
#     713 def rebuild_ctx():
#     714     return optimize(*args, **kwargs)
# --> 716 return _optimize(rebuild_ctx, *args, **kwargs)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:790, in _optimize(rebuild_ctx, backend, nopython, guard_export_fn, guard_fail_fn, disable, dynamic)
#     776     return optimize_assert(
#     777         backend,
#     778         dynamic=dynamic,
#     779         hooks=hooks,
#     780         rebuild_ctx=rebuild_ctx,
#     781     )
#     782 # The backend function is stashed in the callable returned by
#     783 # _optimize_catch_errors in the field _torchdynamo_orig_callable. This can
#     784 # be used by eval_frame.c to insert a guard on the backend.
#     785 return _optimize_catch_errors(
#     786     convert_frame.convert_frame(backend, hooks=hooks),
#     787     hooks,
#     788     backend_ctx_ctor,
#     789     dynamic=dynamic,
# --> 790     compiler_config=backend.get_compiler_config()
#     791     if hasattr(backend, "get_compiler_config")
#     792     else None,
#     793     rebuild_ctx=rebuild_ctx,
#     794 )
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/__init__.py:2237, in _TorchCompileInductorWrapper.get_compiler_config(self)
#    2236 def get_compiler_config(self):
# -> 2237     from torch._inductor.compile_fx import get_patched_config_dict
#    2239     return get_patched_config_dict(config_patches=self.config)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/compile_fx.py:72
#      70 from .debug import DebugContext
#      71 from .decomposition import select_decomp_table
# ---> 72 from .fx_passes.joint_graph import joint_graph_passes
#      73 from .fx_passes.post_grad import post_grad_passes, view_to_reshape
#      74 from .fx_passes.pre_grad import pre_grad_passes
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/fx_passes/joint_graph.py:19
#      17 from ...utils._ordered_set import OrderedSet
#      18 from .. import config
# ---> 19 from ..pattern_matcher import (
#      20     CallFunction,
#      21     init_once_fakemode,
#      22     KeywordArg,
#      23     Match,
#      24     MULTIPLE,
#      25     PatternMatcherPass,
#      26     register_graph_pattern,
#      27     stable_topological_sort,
#      28 )
#      29 from .replace_random import replace_random_passes
#      32 log = logging.getLogger(__name__)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/pattern_matcher.py:96
#      94 from . import config
#      95 from .decomposition import select_decomp_table
# ---> 96 from .lowering import fallback_node_due_to_unsupported_type
#      99 log = logging.getLogger(__name__)
#     100 aten = torch.ops.aten
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/lowering.py:6433
#    6429 # populate lowerings defined in kernel/*
#    6430 from . import kernel
# -> 6433 import_submodule(kernel)
#    6435 from . import quantized_lowerings
#    6438 quantized_lowerings.register_quantized_ops()
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_dynamo/utils.py:2237, in import_submodule(mod)
#    2235 for filename in sorted(os.listdir(os.path.dirname(cast(str, mod.__file__)))):
#    2236     if filename.endswith(".py") and filename[0] != "_":
# -> 2237         importlib.import_module(f"{mod.__name__}.{filename[:-3]}")
#
# File ~/.local/share/anaconda3/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/kernel/custom_op.py:9
#       6 from typing import Any, Optional, Union
#       8 import torch
# ----> 9 from torch._inductor.codegen.subgraph import SubgraphTemplate
#      10 from torch._inductor.ir import Buffer, FixedLayout, ir_node_to_tensor, TensorBox
#      11 from torch._inductor.lowering import lowerings, validate_ir
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/codegen/subgraph.py:10
#       8 from torch._inductor import ir
#       9 from torch._inductor.codegen.common import KernelTemplate
# ---> 10 from torch._inductor.ir import (
#      11     Buffer,
#      12     FixedLayout,
#      13     get_free_symbols,
#      14     get_symbolic_inputs,
#      15     gm_original_output_strides,
#      16     ir_node_to_tensor,
#      17     Layout,
#      18 )
#      19 from torch._inductor.runtime.benchmarking import benchmarker
#      20 from torch._inductor.utils import do_bench_using_profiling
#
# ImportError: cannot import name 'get_free_symbols' from 'torch._inductor.ir' (/home/hliu/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/ir.py)

# %%
import torch
import torch.nn as nn

# 定义一个简单的模型
class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(10, 64)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(64, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# 创建模型和输入
model = SimpleNet()
x = torch.randn(32, 10)  # batch_size=32, input_dim=10

# 使用 torch.compile 编译模型（默认使用 inductor 后端）
compiled_model = torch.compile(model)

# 首次运行会触发编译（可能稍慢），后续运行会更快
output = compiled_model(x)
print(output.shape)  # 应该输出 torch.Size([32, 1])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 23
#      20 x = torch.randn(32, 10)  # batch_size=32, input_dim=10
#      22 # 使用 torch.compile 编译模型（默认使用 inductor 后端）
# ---> 23 compiled_model = torch.compile(model)
#      25 # 首次运行会触发编译（可能稍慢），后续运行会更快
#      26 output = compiled_model(x)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/__init__.py:2447, in compile(model, fullgraph, dynamic, backend, mode, options, disable)
#    2444 else:
#    2445     backend = _TorchCompileWrapper(backend, mode, options, dynamic)
# -> 2447 return torch._dynamo.optimize(
#    2448     backend=backend,
#    2449     nopython=fullgraph,
#    2450     dynamic=dynamic,
#    2451     disable=disable,
#    2452 )(model)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:716, in optimize(*args, **kwargs)
#     713 def rebuild_ctx():
#     714     return optimize(*args, **kwargs)
# --> 716 return _optimize(rebuild_ctx, *args, **kwargs)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:790, in _optimize(rebuild_ctx, backend, nopython, guard_export_fn, guard_fail_fn, disable, dynamic)
#     776     return optimize_assert(
#     777         backend,
#     778         dynamic=dynamic,
#     779         hooks=hooks,
#     780         rebuild_ctx=rebuild_ctx,
#     781     )
#     782 # The backend function is stashed in the callable returned by
#     783 # _optimize_catch_errors in the field _torchdynamo_orig_callable. This can
#     784 # be used by eval_frame.c to insert a guard on the backend.
#     785 return _optimize_catch_errors(
#     786     convert_frame.convert_frame(backend, hooks=hooks),
#     787     hooks,
#     788     backend_ctx_ctor,
#     789     dynamic=dynamic,
# --> 790     compiler_config=backend.get_compiler_config()
#     791     if hasattr(backend, "get_compiler_config")
#     792     else None,
#     793     rebuild_ctx=rebuild_ctx,
#     794 )
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/__init__.py:2237, in _TorchCompileInductorWrapper.get_compiler_config(self)
#    2236 def get_compiler_config(self):
# -> 2237     from torch._inductor.compile_fx import get_patched_config_dict
#    2239     return get_patched_config_dict(config_patches=self.config)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/compile_fx.py:72
#      70 from .debug import DebugContext
#      71 from .decomposition import select_decomp_table
# ---> 72 from .fx_passes.joint_graph import joint_graph_passes
#      73 from .fx_passes.post_grad import post_grad_passes, view_to_reshape
#      74 from .fx_passes.pre_grad import pre_grad_passes
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/fx_passes/joint_graph.py:19
#      17 from ...utils._ordered_set import OrderedSet
#      18 from .. import config
# ---> 19 from ..pattern_matcher import (
#      20     CallFunction,
#      21     init_once_fakemode,
#      22     KeywordArg,
#      23     Match,
#      24     MULTIPLE,
#      25     PatternMatcherPass,
#      26     register_graph_pattern,
#      27     stable_topological_sort,
#      28 )
#      29 from .replace_random import replace_random_passes
#      32 log = logging.getLogger(__name__)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/pattern_matcher.py:96
#      94 from . import config
#      95 from .decomposition import select_decomp_table
# ---> 96 from .lowering import fallback_node_due_to_unsupported_type
#      99 log = logging.getLogger(__name__)
#     100 aten = torch.ops.aten
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/lowering.py:6433
#    6429 # populate lowerings defined in kernel/*
#    6430 from . import kernel
# -> 6433 import_submodule(kernel)
#    6435 from . import quantized_lowerings
#    6438 quantized_lowerings.register_quantized_ops()
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_dynamo/utils.py:2237, in import_submodule(mod)
#    2235 for filename in sorted(os.listdir(os.path.dirname(cast(str, mod.__file__)))):
#    2236     if filename.endswith(".py") and filename[0] != "_":
# -> 2237         importlib.import_module(f"{mod.__name__}.{filename[:-3]}")
#
# File ~/.local/share/anaconda3/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/kernel/custom_op.py:9
#       6 from typing import Any, Optional, Union
#       8 import torch
# ----> 9 from torch._inductor.codegen.subgraph import SubgraphTemplate
#      10 from torch._inductor.ir import Buffer, FixedLayout, ir_node_to_tensor, TensorBox
#      11 from torch._inductor.lowering import lowerings, validate_ir
#
# File ~/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/codegen/subgraph.py:10
#       8 from torch._inductor import ir
#       9 from torch._inductor.codegen.common import KernelTemplate
# ---> 10 from torch._inductor.ir import (
#      11     Buffer,
#      12     FixedLayout,
#      13     get_free_symbols,
#      14     get_symbolic_inputs,
#      15     gm_original_output_strides,
#      16     ir_node_to_tensor,
#      17     Layout,
#      18 )
#      19 from torch._inductor.runtime.benchmarking import benchmarker
#      20 from torch._inductor.utils import do_bench_using_profiling
#
# ImportError: cannot import name 'get_free_symbols' from 'torch._inductor.ir' (/home/hliu/.local/share/anaconda3/lib/python3.10/site-packages/torch/_inductor/ir.py)
